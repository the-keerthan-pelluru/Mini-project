# %%
#importing warnings
import os
import warnings
warnings.simplefilter('ignore')

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from skimage.io import imread, imshow
from skimage.transform import resize
from skimage.color import rgb2gray

# %%
a = os.listdir("C:/Users/PK REDDY/Desktop/Assignment/Test/Keerthan")

# %%
b = os.listdir("C:/Users/PK REDDY/Desktop/Assignment/Test/Jagan")

# %%
c = os.listdir("C:/Users/PK REDDY/Desktop/Assignment/Test/Emadh")

# %%
limit = 10
a_images =[None]*limit
j=0
for i in a:
    if(j<limit):
        a_images[j] = imread("C:/Users/PK REDDY/Desktop/Assignment/Test/Keerthan/"+i)
        j+=1
    else:
        break

# %%
limit = 10
b_images =[None]*limit
j=0
for i in b:
    if(j<limit):
        b_images[j] = imread("C:/Users/PK REDDY/Desktop/Assignment/Test/Jagan/"+i)
        j+=1
    else:
        break

# %%
limit = 10
c_images =[None]*limit
j=0
for i in c:
    if(j<limit):
        c_images[j] = imread("C:/Users/PK REDDY/Desktop/Assignment/Test/Emadh/"+i)
        j+=1
    else:
        break

# %%
imshow(a_images[0])

# %%
imshow(b_images[0])

# %%
imshow(c_images[0])

# %%
a_gray = [None]*limit
j=0
for i in a:
    if (j<limit):
        a_gray[j] = rgb2gray(a_images[j][:,:,:3])
        j+=1
    else:
        break

# %%
b_gray = [None]*limit
j=0
for i in b:
    if (j<limit):
        b_gray[j] = rgb2gray(b_images[j][:,:,:3])
        j+=1
    else:
        break

# %%
c_gray = [None]*limit
j=0
for i in c:
    if (j<limit):
        c_gray[j] = rgb2gray(c_images[j][:,:,:3])
        j+=1
    else:
        break

# %%
imshow(a_gray[0])

# %%
imshow(b_gray[0])

# %%
imshow(c_gray[0])

# %%
a_gray[0].shape
# Out:
# (1078, 1079)

# %%
b_gray[0].shape
# Out:
# (1069, 806)

# %%
c_gray[0].shape
# Out:
# (1600, 1200)

# %%
for j in range (10):
    rk = a_gray[j]
    a_gray[j] = resize(rk,(512,512))

# %%
for j in range (10):
    rk = b_gray[j]
    b_gray[j] = resize(rk,(512,512))

# %%
for j in range (10):
    rk = c_gray[j]
    c_gray[j] = resize(rk,(512,512))

# %%
imshow(a_gray[0])

# %%
imshow(b_gray[0])

# %%
imshow(c_gray[0])

# %%
a_gray[0].shape
b_gray[0].shape
c_gray[0].shape
# Out:
# (512, 512)

# %%
len_of_images_a = len(a_gray)
len_of_images_a
# Out:
# 10

# %%
len_of_images_b = len(b_gray)
len_of_images_b
# Out:
# 10

# %%
len_of_images_c = len(c_gray)
len_of_images_c
# Out:
# 10

# %%
image_size_of_a=a_gray[1].shape
image_size_of_a
# Out:
# (512, 512)

# %%
image_size_of_b=b_gray[1].shape
image_size_of_b
# Out:
# (512, 512)

# %%
image_size_of_c=c_gray[1].shape
image_size_of_c
# Out:
# (512, 512)

# %%
flatten_size_a = image_size_of_a[0]*image_size_of_a[1]
flatten_size_a
# Out:
# 262144

# %%
flatten_size_b = image_size_of_b[0]*image_size_of_b[1]
flatten_size_b
# Out:
# 262144

# %%
flatten_size_c = image_size_of_c[0]*image_size_of_c[1]
flatten_size_c
# Out:
# 262144

# %%
for i in range(len_of_images_a):
    a_gray[i]=np.ndarray.flatten(a_gray[i]).reshape(flatten_size_a,1)

# %%
for i in range(len_of_images_b):
    b_gray[i]=np.ndarray.flatten(b_gray[i]).reshape(flatten_size_b,1)

# %%
for i in range(len_of_images_c):
    c_gray[i]=np.ndarray.flatten(c_gray[i]).reshape(flatten_size_c,1)

# %%
a_gray[7].shape
# Out:
# (262144, 1)

# %%
b_gray[7].shape
# Out:
# (262144, 1)

# %%
c_gray[7].shape
# Out:
# (262144, 1)

# %%
a_gray = np.dstack(a_gray)
a_gray.shape
# Out:
# (262144, 1, 10)

# %%
b_gray = np.dstack(b_gray)
b_gray.shape
# Out:
# (262144, 1, 10)

# %%
c_gray = np.dstack(c_gray)
c_gray.shape
# Out:
# (262144, 1, 10)

# %%
a_gray=np.rollaxis(a_gray,axis=2,start=0)
a_gray.shape
# Out:
# (10, 262144, 1)

# %%
b_gray=np.rollaxis(b_gray,axis=2,start=0)
b_gray.shape
# Out:
# (10, 262144, 1)

# %%
c_gray=np.rollaxis(c_gray,axis=2,start=0)
c_gray.shape
# Out:
# (10, 262144, 1)

# %%
a_gray=a_gray.reshape(len_of_images_a,flatten_size_a)
a_gray.shape
# Out:
# (10, 262144)

# %%
b_gray=b_gray.reshape(len_of_images_b,flatten_size_b)
b_gray.shape
# Out:
# (10, 262144)

# %%
c_gray=c_gray.reshape(len_of_images_c,flatten_size_c)
c_gray.shape
# Out:
# (10, 262144)

# %%
a_data=pd.DataFrame(a_gray)
a_data
# Out:
#      0         1         2         3         4         5         6       \
# 0  0.364570  0.352235  0.362147  0.352664  0.330483  0.331591  0.317048
# 1  0.330881  0.329158  0.325281  0.322885  0.321166  0.321159  0.321159
# 2  0.086297  0.071024  0.094833  0.066251  0.036947  0.057717  0.048653
# 3  0.999963  0.969650  0.806423  0.780939  0.774841  0.787474  0.799686
# 4  0.815686  0.815686  0.815686  0.815686  0.815686  0.815691  0.818642
# 5  0.831547  0.831547  0.831286  0.829215  0.829553  0.833195  0.837393
# 6  0.948709  0.618580  0.424067  0.419022  0.436339  0.430631  0.436622
# 7  0.138897  0.145686  0.164480  0.165617  0.126314  0.059045  0.121216
# 8  0.219163  0.184728  0.181890  0.191749  0.232129  0.216922  0.286935
# 9  0.850300  0.891962  0.718323  0.744569  0.741531  0.644493  0.648120
#
#      7         8         9       ...    262134    262135    262136    262137  \
# 0  0.360463  0.298409  0.251523  ...  0.097765  0.107480  0.120738  0.138738
# ...

# %%
b_data=pd.DataFrame(b_gray)
b_data
# Out:
#      0         1         2         3         4         5             6       \
# 0  0.131192  0.130854  0.128449  0.127662  0.125324  0.132306  1.302719e-01
# 1  0.641342  0.612263  0.440009  0.158876  0.478724  0.490521  4.760798e-01
# 2  0.026413  0.016761  0.019182  0.016398  0.015829  0.019258  1.693670e-02
# 3  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000e+
# 1   0.987733  0.941223  0.915946  0.914557  0.912444  0.902449  9.013719e-01
# 2   0.224462  0.224741  0.227206  0.231286  0.232193  0.221895  2.030082e-01
# 3   0.006998  0.007083  0.007167  0.007252  0.007337  0.007279  7.193608e-03
# 4   0.380554  0.404922  0.376435  0.381623  0.419277  0.412946  4.197385e-01
# 5   0.990165  0.994210  0.377022  0.003493  0.012316  0.006311  5.823234e-11
# 6   0.364570  0.352235  0.362147  0.352664  0.330483  0.331591  3.170482e-01
# 7   0.732788  0.730013  0.726598  0.724025  0.720877  0.717311  7.150081e-01
# 8   0.086297  0.071024  0.094833  0.066251  0.036947  0.057717  4.865264e-02
# 9   0.665660  0.665673  0.665686  0.666053  0.668558  0.668559  6.685452e-01
# 10  0.138897  0.145686  0.164480  0.165617  0.126314  0.059045  1.212156e-01
# ...

# %%
x=Faces_indexed.values[:,:-1]

# %%
y=Faces_indexed.values[:,-1]

# %%
x
# Out:
# array([[0.9858254584372325, 0.9567200662803697, 0.9252173089274285, ...,
#         0.6333893653843288, 0.713402148717594, 0.6689015728289808],
#        [0.987732538948996, 0.9412232413140407, 0.9159459877500438, ...,
#         0.6040270511695387, 0.5980912273749364, 0.6146218874448],
#        [0.22446201700180146, 0.22474112454280287, 0.2272058879261832,
#         ..., 0.29764430533221803, 0.30633490989798795, 0.31346918473336],
#        ...,
#        [0.9999632928306975, 0.9696500125929788, 0.8064228538794724, ...,
#         1.0, 1.0, 1.0],
#        [0.013530226725293184, 0.013530226725293184, 0.013530226725293183,
#         ..., 0.19248582472486436, 0.18958338403563027,
#         0.1861624102034562],
#        [0.6562954772340449, 0.6534426750877877, 0.6507148437825674, ...,
#         1.0, 1.0, 1.0]], dtype=object)

# %%
y
# Out:
# array(['Jagan', 'Jagan', 'Emadh Ahamed', 'Emadh Ahamed', 'Emadh Ahamed',
#        'Jagan', 'Pelluru Keerthan', 'Emadh Ahamed', 'Pelluru Keerthan',
#        'Emadh Ahamed', 'Pelluru Keerthan', 'Pelluru Keerthan',
#        'Emadh Ahamed', 'Jagan', 'Jagan', 'Jagan', 'Jagan', 'Emadh Ahamed',
#        'Pelluru Keerthan', 'Emadh Ahamed', 'Jagan', 'Pelluru Keerthan',
#        'Pelluru Keerthan', 'Jagan', 'Emadh Ahamed', 'Pelluru Keerthan',
#        'Pelluru Keerthan', 'Pelluru Keerthan', 'Emadh Ahamed', 'Jagan'],
#       dtype=object)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.2,random_state=0)

# %%
from sklearn import svm
clf=svm.SVC()
clf.fit(x_train,y_train)
# Out:
# SVC()

# %%
y_pred=clf.predict(x_test)
y_pred
# Out:
# array(['Emadh Ahamed', 'Emadh Ahamed', 'Jagan', 'Jagan',
#        'Pelluru Keerthan', 'Emadh Ahamed'], dtype=object)

# %%
for i in (np.random.randint(0,6,4)):
    pred_images=(np.reshape(x_test[i],(512,512)).astype(np.float64))
    plt.title('predict lable:{0}'.format(y_pred[i]))
    plt.imshow(pred_images, interpolation='nearest',cmap="gray")
    plt.show()

# %%
from sklearn import metrics
accuracy=metrics.accuracy_score(y_test,y_pred)
accuracy
# Out:
# 0.8333333333333334

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,y_pred)
# Out:
# array([[3, 0, 0],
#        [0, 1, 0],
#        [0, 1, 1]], dtype=int64)
